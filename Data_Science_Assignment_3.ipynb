# %% [markdown]
# <a href="https://colab.research.google.com/github/mariumfaheem/data-science-assignment-/blob/main/Data_Science_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/netflix_data.csv")
df
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# # Lets do some data cleaning and wrangling

# %%
missing_values=df.isnull()
missing_values

# %%
for columns in missing_values.columns.values.tolist():
  print(columns)
  print(missing_values[columns].value_counts())
  print(" ")
# Out:
# show_id
# False    7787
# Name: show_id, dtype: int64
#
# type
# False    7787
# Name: type, dtype: int64
#
# title
# False    7787
# Name: title, dtype: int64
#
# director
# False    5398
# True     2389
# Name: director, dtype: int64
#
# cast
# False    7069
# True      718
# Name: cast, dtype: int64
#
# country
# False    7280
# True      507
# Name: country, dtype: int64
#
# date_added
# False    7777
# True       10
# Name: date_added, dtype: int64
#
# release_year
# False    7787
# Name: release_year, dtype: int64
#
# duration
# False    7787
# Name: duration, dtype: int64
#
# description
# False    7787
# Name: description, dtype: int64
#
# genre
# False    7787
# Name: genre, dtype: int64

# %% [markdown]
# lets remove all null values

# %%
df.dropna(inplace=True)

# %%
missing_values=df.isnull()
missing_values

for columns in missing_values.columns.values.tolist():
  print(columns)
  print(missing_values[columns].value_counts())
  print(" ")
# Out:
# show_id
# False    4812
# Name: show_id, dtype: int64
#
# type
# False    4812
# Name: type, dtype: int64
#
# title
# False    4812
# Name: title, dtype: int64
#
# director
# False    4812
# Name: director, dtype: int64
#
# cast
# False    4812
# Name: cast, dtype: int64
#
# country
# False    4812
# Name: country, dtype: int64
#
# date_added
# False    4812
# Name: date_added, dtype: int64
#
# release_year
# False    4812
# Name: release_year, dtype: int64
#
# duration
# False    4812
# Name: duration, dtype: int64
#
# description
# False    4812
# Name: description, dtype: int64
#
# genre
# False    4812
# Name: genre, dtype: int64

# %% [markdown]
# # No Missing Values

# %% [markdown]
# # Assignment Question No.1

# %%
count=len(df.loc[1,"cast"].split(","))
count
# Out:
# 6

# %%
def return_count(val):
  if val is None:
    return 0
  else:
    return len(val.split(","))

# %%
df["num_of_cast"]=df["cast"].apply(return_count)

# %%
df.head()
# Out:
#   show_id     type  title           director  \
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 cast        country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#           date_added  release_year  duration  \
# 1  December 23, 2016          2016        93
# 2  December 20, 2018          2011        78
# 3  November 16, 2017          2009        80
# 4    January 1, 2020          2008       123
# 5       July 1, 2017          2016         1
#
# ...

# %% [markdown]
# # Assignment Question No.2

# %%
df.groupby("type")["genre"].value_counts()
# Out:
# type     genre
# Movie    Dramas                  1343
#          Comedies                1029
#          Action                   696
#          Children                 421
#          Documentaries            352
#          Stand-Up                 276
#          Horror Movies            239
#          International Movies     100
#          Classic Movies            69
#          Thrillers                 49
#          Uncategorized             25
#          Independent Movies        20
#          Anime Features            18
#          Music                     14
#          Cult Movies               11
#          Sci-Fi                    11
#          Romantic Movies            3
#          LGBTQ Movies               1
# TV Show  International TV          39
#          Crime TV                  30
#          British TV                20
#          Kids                      10
#          Anime Series               9
#          Docuseries                 7
# ...
